# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\SHRADDHA SINGH\OneDrive\Desktop\MCA\data analytics/tested.csv")

# %%
df.head(5)
# Out:
#      PassengerId   Survived      Pclass  \
# 892            0          3      "Kelly
# 893            1          3     "Wilkes
# 894            0          2      "Myles
# 895            0          3       "Wirz
# 896            1          3   "Hirvonen
#
#      Name                                                               \
# 892   Mr. James"                                   ...
# 893   Mrs. James (Ellen Needs)"                    ...
# 894   Mr. Thomas Francis"                          ...
# 895   Mr. Albert"                                  ...
# 896   Mrs. Alexander (Helga E Lindqvist)"          ...
#
#       Sex      Age    SibSp   Parch   Ticket               Fare      \
# 892   male     34.5       0       0   330911               7.8292
# 893   female   47         1       0   363272               7
# 894   male     62         0       0   240276               9.6875
# 895   male     27         0       0   315154               8.6625
# ...

# %%
df.tail(10)
# Out:
#       PassengerId   Survived           Pclass  \
# 1300            1          3         "Riordan
# 1301            1          3         "Peacock
# 1302            1          3        "Naughton
# 1303            1          1         "Minahan
# 1304            1          3      "Henriksson
# 1305            0          3         "Spector
# 1306            1          1   "Oliva y Ocana
# 1307            0          3         "Saether
# 1308            0          3            "Ware
# 1309            0          3           "Peter
#
#       Name                                                               \
# 1300   Miss. Johanna Hannah"""""                    ...
# 1301   Miss. Treasteall"                            ...
# 1302   Miss. Hannah"                                ...
# 1303   Mrs. William Edward (Lillian E Thorpe)"      ...
# 1304   Miss. Jenny Lovisa"                          ...
# 1305   Mr. Woolf"                                   ...
# ...

# %%
df.dtypes
# Out:
# PassengerId                                                            int64
#  Survived                                                              int64
#  Pclass                                                               object
#  Name                                                                 object
#  Sex                                                                  object
#  Age                                                                  object
#  SibSp                                                                 int64
#  Parch                                                                 int64
#  Ticket                                                               object
#  Fare                                                                 object
#  Cabin                                                                object
#  Embarked                                                             object
# dtype: object

# %%
df.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of       PassengerId   Survived           Pclass  \
# 892             0          3           "Kelly
# 893             1          3          "Wilkes
# 894             0          2           "Myles
# 895             0          3            "Wirz
# 896             1          3        "Hirvonen
# ...           ...        ...              ...
# 1305            0          3         "Spector
# 1306            1          1   "Oliva y Ocana
# 1307            0          3         "Saether
# 1308            0          3            "Ware
# 1309            0          3           "Peter
#
#       Name                                                               \
# 892    Mr. James"                                   ...
# 893    Mrs. James (Ellen Needs)"                    ...
# 894    Mr. Thomas Francis"                          ...
# 895    Mr. Albert"                                  ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived       SibSp       Parch
# count   418.000000  418.000000  418.000000  418.000000
# mean      0.363636    2.265550    0.447368    0.392344
# std       0.481622    0.841838    0.896760    0.981429
# min       0.000000    1.000000    0.000000    0.000000
# 25%       0.000000    1.000000    0.000000    0.000000
# 50%       0.000000    3.000000    0.000000    0.000000
# 75%       1.000000    3.000000    1.000000    0.000000
# max       1.000000    3.000000    8.000000    9.000000

# %%
df
# Out:
#       PassengerId   Survived           Pclass  \
# 892             0          3           "Kelly
# 893             1          3          "Wilkes
# 894             0          2           "Myles
# 895             0          3            "Wirz
# 896             1          3        "Hirvonen
# ...           ...        ...              ...
# 1305            0          3         "Spector
# 1306            1          1   "Oliva y Ocana
# 1307            0          3         "Saether
# 1308            0          3            "Ware
# 1309            0          3           "Peter
#
#       Name                                                               \
# 892    Mr. James"                                   ...
# 893    Mrs. James (Ellen Needs)"                    ...
# 894    Mr. Thomas Francis"                          ...
# 895    Mr. Albert"                                  ...
# 896    Mrs. Alexander (Helga E Lindqvist)"          ...
# ...

# %%
df[['Name','Sex','Cabin','Embarked'  ]
# Out:
#   Cell In[72], line 1
#     df[['Name','Sex','Cabin','Embarked'  ]
#                                           ^
# SyntaxError: incomplete input

# %%
df.dtypes == 'object'
# Out:
# PassengerId                                                           False
#  Survived                                                             False
#  Pclass                                                                True
#  Name                                                                  True
#  Sex                                                                   True
#  Age                                                                   True
#  SibSp                                                                False
#  Parch                                                                False
#  Ticket                                                                True
#  Fare                                                                  True
#  Cabin                                                                 True
#  Embarked                                                              True
# dtype: bool

# %%
df.columns
# Out:
# Index(['PassengerId', ' Survived', ' Pclass',
#        ' Name                                                             ',
#        ' Sex   ', ' Age ', ' SibSp', ' Parch', ' Ticket            ',
#        ' Fare    ', ' Cabin          ', ' Embarked'],
#       dtype='object')

# %%
df
# Out:
#       PassengerId   Survived           Pclass  \
# 892             0          3           "Kelly
# 893             1          3          "Wilkes
# 894             0          2           "Myles
# 895             0          3            "Wirz
# 896             1          3        "Hirvonen
# ...           ...        ...              ...
# 1305            0          3         "Spector
# 1306            1          1   "Oliva y Ocana
# 1307            0          3         "Saether
# 1308            0          3            "Ware
# 1309            0          3           "Peter
#
#       Name                                                               \
# 892    Mr. James"                                   ...
# 893    Mrs. James (Ellen Needs)"                    ...
# 894    Mr. Thomas Francis"                          ...
# 895    Mr. Albert"                                  ...
# 896    Mrs. Alexander (Helga E Lindqvist)"          ...
# ...

# %%
a = df[' Name                                                             '][0:10]

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
#set the index
I = ['a0','a1','a2','a3','a4','a5','a6','a7','a8','a9']

# %%
pd.Series(a, index=I)
# Out:
# a0    NaN
# a1    NaN
# a2    NaN
# a3    NaN
# a4    NaN
# a5    NaN
# a6    NaN
# a7    NaN
# a8    NaN
# a9    NaN
# Name:  Name                                                             , dtype: object

# %%
pd.Series(list(a), index=I)
# Out:
# a0     Mr. James"                                   ...
# a1     Mrs. James (Ellen Needs)"                    ...
# a2     Mr. Thomas Francis"                          ...
# a3     Mr. Albert"                                  ...
# a4     Mrs. Alexander (Helga E Lindqvist)"          ...
# a5     Mr. Johan Cervin"                            ...
# a6     Miss. Kate"                                  ...
# a7     Mr. Albert Francis"                          ...
# a8     Mrs. Joseph (Sophie Halaut Easu)"            ...
# a9     Mr. John Samuel"                             ...
# dtype: object

# %%
#delete the column 
df.drop("PassengerId" , axis=1)
# Out:
#        Survived           Pclass  \
# 892           3           "Kelly
# 893           3          "Wilkes
# 894           2           "Myles
# 895           3            "Wirz
# 896           3        "Hirvonen
# ...         ...              ...
# 1305          3         "Spector
# 1306          1   "Oliva y Ocana
# 1307          3         "Saether
# 1308          3            "Ware
# 1309          3           "Peter
#
#       Name                                                               \
# 892    Mr. James"                                   ...
# 893    Mrs. James (Ellen Needs)"                    ...
# 894    Mr. Thomas Francis"                          ...
# 895    Mr. Albert"                                  ...
# 896    Mrs. Alexander (Helga E Lindqvist)"          ...
# ...                                                 ...
# 1305   Mr. Woolf"                                   ...
# 1306   Dona. Fermina"                               ...
# ...

# %%
#insert the column

# %%
#delete parmanently the column 
df.drop("PassengerId" , axis=1 , inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[89], line 2
#       1 #delete parmanently the column
# ----> 2 df.drop("PassengerId" , axis=1 , inplace=True)
#
# File c:\Users\SHRADDHA SINGH\miniconda3\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
# ...

# %%
df
# Out:
#        Survived           Pclass  \
# 892           3           "Kelly
# 893           3          "Wilkes
# 894           2           "Myles
# 895           3            "Wirz
# 896           3        "Hirvonen
# ...         ...              ...
# 1305          3         "Spector
# 1306          1   "Oliva y Ocana
# 1307          3         "Saether
# 1308          3            "Ware
# 1309          3           "Peter
#
#       Name                                                               \
# 892    Mr. James"                                   ...
# 893    Mrs. James (Ellen Needs)"                    ...
# 894    Mr. Thomas Francis"                          ...
# 895    Mr. Albert"                                  ...
# 896    Mrs. Alexander (Helga E Lindqvist)"          ...
# ...                                                 ...
# 1305   Mr. Woolf"                                   ...
# 1306   Dona. Fermina"                               ...
# ...

# %%
#delete the row

df.drop(1304 , inplace=True)
df
# Out:
#        Survived      Pclass  \
# 892           3      "Kelly
# 893           3     "Wilkes
# 894           2      "Myles
# 895           3       "Wirz
# 896           3   "Hirvonen
# ...         ...         ...
# 1302          3   "Naughton
# 1303          1    "Minahan
# 1307          3    "Saether
# 1308          3       "Ware
# 1309          3      "Peter
#
#       Name                                                               \
# 892    Mr. James"                                   ...
# 893    Mrs. James (Ellen Needs)"                    ...
# 894    Mr. Thomas Francis"                          ...
# 895    Mr. Albert"                                  ...
# 896    Mrs. Alexander (Helga E Lindqvist)"          ...
# ...                                                 ...
# 1302   Miss. Hannah"                                ...
# 1303   Mrs. William Edward (Lillian E Thorpe)"      ...
# 1307   Mr. Simon Sivertsen"                         ...
# ...

# %%
df.head()
# Out:
#       Survived      Pclass  \
# 892          3      "Kelly
# 893          3     "Wilkes
# 894          2      "Myles
# 895          3       "Wirz
# 896          3   "Hirvonen
#
#      Name                                                               \
# 892   Mr. James"                                   ...
# 893   Mrs. James (Ellen Needs)"                    ...
# 894   Mr. Thomas Francis"                          ...
# 895   Mr. Albert"                                  ...
# 896   Mrs. Alexander (Helga E Lindqvist)"          ...
#
#       Sex      Age    SibSp   Parch   Ticket               Fare      \
# 892   male     34.5       0       0   330911               7.8292
# 893   female   47         1       0   363272               7
# 894   male     62         0       0   240276               9.6875
# 895   male     27         0       0   315154               8.6625
# 896   female   22         1       1   3101298              12.2875
#
#       Cabin            Embarked
# ...
